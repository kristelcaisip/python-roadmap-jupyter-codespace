# %% [markdown]
# # Data Structures
#
# ## 1 Basic
#
# ### 1.1 Arrays
# ### 1.2 Lists
# ### 1.3 Tuples
# ### 1.4 Sets
#
# ## 2 Advanced
# ### 2.1 Stacks
# ### 2.2 Linked Lists
# ### 2.3 Dictionaries
# ### 2.4 Queues
