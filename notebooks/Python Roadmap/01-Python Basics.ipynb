# %% [markdown]
# # Python Basics
#
# ## 1 Operators
#
# ### 1.1 Arithmetic

# %%
x = 4
y = 20

print(f"Demo-ing the Arithmetic Operators")

sum = y + x
print(f"Sum: {sum}")

difference = y - x
print(f"Difference: {difference}")

product = y * x
print(f"Product: {product}")

quotient = y/x
print(f"Quotient: {quotient}")
# Out:
# Demo-ing the Arithmetic Operators
# Sum: 24
# Difference: 16
# Product: 80
# Quotient: 5.0

# %% [markdown]
# ### 1.2 Comparisons

# %%
# Comparisons

# %% [markdown]
# ### 1.3 Logical (and, or, not)

# %%
# Logical

# %% [markdown]
# ## 2 Control Structures

# %%
# Conditionals (if, elif, else)
# Loops (for, while, do while)

# %% [markdown]
# ## 3 Functions and Error Handling

# %%
# Functions and Error Handling
