# %% [markdown]
# # Advanced Topics
#
# ## 1 Recursion
# ## 2 Modules and Packages
# ## 3 Iterators
# ## 4 Generators
# ## 5 Comprehensions
# ## 6 Context Manager
# ## 7 Dunder Methods
# ## 8 Regular Expressions
# ## 9 Lambda Functions
